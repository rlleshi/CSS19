# %%
import pandas as pd 
import tensorflow
from bs4 import BeautifulSoup
import re
import timeit
import requests

# %%
def check_module():

# %%
def crawl_module():

# %%
startTime = timeit.default_timer()

seedURL = "https://en.wikipedia.org/wiki/Wikipedia:Archived_deletion_discussions#Deletion_discussions/"
archivePage = requests.get(seedURL)
soup = BeautifulSoup(page.content, "html.parser")
toBeCrawledURLS = soup.find_all("ul", limit=2)[1]
print(toBeCrawledURLS.prettify())

elapsedTime = timeit.default_timer() - startTime
print("Crawl time ", elapsedTime)
# Out:
# <ul>
#  <li class="toclevel-1 tocsection-1">
#   <a href="#2019">
#    <span class="tocnumber">
#     1
#    </span>
#    <span class="toctext">
#     2019
#    </span>
#   </a>
#   <ul>
#    <li class="toclevel-2 tocsection-2">
#     <a href="#Deletion_discussions/2019_May">
#      <span class="tocnumber">
#       1.1
#      </span>
#      <span class="toctext">
#       Deletion discussions/2019 May
#      </span>
#     </a>
#    </li>
#    <li class="toclevel-2 tocsection-3">
#     <a href="#Deletion_discussions/2019_April">
#      <span class="tocnumber">
#       1.2
#      </span>
#      <span class="toctext">
#       Deletion discussions/2019 April
#      </span>
#     </a>
#    </li>
#    <li class="toclevel-2 tocsection-4">
#     <a href="#Deletion_discussions/2019_March">
#      <span class="tocnumber">
#       1.3
#      </span>
#      <span class="toctext">
#       Deletion discussions/2019 March
#      </span>
#     </a>
#    </li>
# ...
