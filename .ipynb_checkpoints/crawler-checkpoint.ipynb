# %%
import pandas as pd 
import tensorflow
from bs4 import BeautifulSoup
import re
import timeit
import requests
import wikipedia

# %%
def crawl_year(year, yearContent, df):
    for monthContent in yearContent.find_next_siblings(limit=24):
        if monthContent.name == "h2":
            continue
            # or break? Make Tests
        if monthContent.name == "h3":
            month = monthContent.get_text().split(str(year)+" ")[1].split("[")[0]
            print("Month",month)
        if monthContent.name == "ul":
            for dayRelative in monthContent.find_all("a"):
                print(dayRelative['href'])
                dayPageLink = "https://en.wikipedia.org/"+dayRelative['href']
                try :
                    dayPage = requests.get(dayPageLink)
                except requests.exceptions.RequestException as e:
                    continue
                soupPage = BeautifulSoup(dayPage.content, "html.parser")
            
                if dayPage.status_code == 200:
                    try:
                        # Find the last article to get the length of the articles
                        articlesLength = int(soupPage.find_all("ul")[2].find_all("li")[-1].get_text().split(" ")[0])
                    except ValueError:
                        continue
                    # Every article is located in an <h3> tag
                    for article in soupPage.find_all("h3", limit = articlesLength):
                        # Don't read deleted articles
                        if article.find("a")['title'].find("(page does") == -1:
                            articleTitle = article.get_text().split("[")[0]
#                             pageLink = "https://en.wikipedia.org"+article.find("a")['href']
                            df = crawl_article(year, month, articleTitle, df)
    return df

# %%
def crawl_article(year, month, articleTitle, df):
    try: 
        p = wikipedia.page(articleTitle)
    except wikipedia.exceptions.DisambiguationError as e:
        return df
    dic = {"Year":year, "Month":month, "Title": p.title, "Content": p.content, "About_women":0}
    if df.empty:
        df = pd.DataFrame(data=dic, index=[0])
    else:
        df_temp = pd.DataFrame(data=dic, index=[0])
        df = pd.concat([df, df_temp])
    return df

# %%
startTime = timeit.default_timer()

seedURL = "https://en.wikipedia.org/wiki/Wikipedia:Archived_deletion_discussions#Deletion_discussions/"
archivePage = requests.get(seedURL)
soup = BeautifulSoup(archivePage.content, "html.parser")

# Get the year
years = []
yearContents = []
for yearContent in soup.find_all("h2", limit=7):
    year = yearContent.get_text().split("[")[0]
    if year == "Contents":
        continue
    years.append(year)
    yearContents.append(yearContent)
    
df = pd.DataFrame()
df = crawl_year(years[0], yearContents[0], df)


# yearContent = soup.find_all("h2", limit=5)[1]
# year=yearContent.get_text().split("[")[0]

# print(yearContent.prettify())


elapsedTime = timeit.default_timer() - startTime
print("Crawl time ", elapsedTime)
# Out:
# Month June
# <h3>
#  <span id="Deletion_discussions.2F2019_June">
#  </span>
#  <span class="mw-headline" id="Deletion_discussions/2019_June">
#   Deletion discussions/2019 June
#  </span>
#  <span class="mw-editsection">
#   <span class="mw-editsection-bracket">
#    [
#   </span>
#   <a href="/w/index.php?title=Wikipedia:Archived_deletion_discussions&amp;action=edit&amp;section=2" title="Edit section: Deletion discussions/2019 June">
#    edit
#   </a>
#   <span class="mw-editsection-bracket">
#    ]
#   </span>
#  </span>
# </h3>
#
# /wiki/Wikipedia:Articles_for_deletion/Log/2019_June_5

# %%
crawl_article(2010, 12, "Ramsey Island",  df)
# Out:
#    Year  Month          Title  \
# 0  2010     12  Ramsey Island
#
#                                              Content  About_women
# 0  Ramsey Island (Welsh: Ynys Dewi) is an island ...            0

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
len(articlesName)
# Out:
# 0

# %%
# Get the day
may28thLink = "https://en.wikipedia.org/" + monthContent.find_all("a")[0]['href']
page = requests.get(may28thLink)
soupPage = BeautifulSoup(page.content, "html.parser")
print(soupPage.prettify())
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    Wikipedia:Articles for deletion/Log/2019 May 28 - Wikipedia
#   </title>
#   <script>
# ...

# %%
# Get the number of articles from the Contents section
articlesLength = int(soupPage.find_all("ul")[2].find_all("li")[-1].get_text().split(" ")[0])
for article in soupPage.find_all("h3", limit = articlesLength):
    if article.find("a")['title'].find("(page does") == -1:
        print(article.get_text().split("[")[0])
# Out:
# Ingrid Detter de Frankopan
# Cyrus S. Poonawalla
# Hongmeng OS
# AeroText
# Star 107.9
# Mark Forstater
# Topshelf Records
# You're Underfed, I'm Wonderful
# David Shing
# Masked Republic

# %%
# Out:
# '46'

# %%
help(ValueError)
# Out:
# Help on class ValueError in module builtins:
#
# class ValueError(Exception)
#  |  Inappropriate argument value (of correct type).
#  |
#  |  Method resolution order:
#  |      ValueError
#  |      Exception
#  |      BaseException
#  |      object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, /, *args, **kwargs)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  __new__(*args, **kwargs) from builtins.type
#  |      Create and return a new object.  See help(type) for accurate signature.
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from BaseException:
#  |
#  |  __delattr__(self, name, /)
#  |      Implement delattr(self, name).
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __reduce__(...)
#  |      helper for pickle
#  |
#  |  __repr__(self, /)
#  |      Return repr(self).
#  |
#  |  __setattr__(self, name, value, /)
# ...

# %%
help(requests.exceptions.DisambiguationError)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-78-a904d4c114e7> in <module>
# ----> 1 help(requests.exceptions.DisambiguationError)
#
# AttributeError: module 'requests.exceptions' has no attribute 'DisambiguationError'
